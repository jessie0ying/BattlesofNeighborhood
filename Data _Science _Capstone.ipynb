# %% [markdown]
# ## **Final Project - Data Science Capstone**

# %%
import numpy as np # library to handle data in a vectorized manner
import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import json # library to handle JSON files
#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe
# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors
# import k-means from clustering stage
from sklearn.cluster import KMeans
from sklearn.datasets.samples_generator import make_blobs
# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library
print('Libraries imported.')
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     altair-4.1.0               |             py_1         614 KB  conda-forge
#     branca-0.4.1               |             py_0          26 KB  conda-forge
#     brotlipy-0.7.0             |py36h8c4c3a4_1000         346 KB  conda-forge
#     ca-certificates-2020.4.5.2 |       hecda079_0         147 KB  conda-forge
#     certifi-2020.4.5.2         |   py36h9f0ad1d_0         152 KB  conda-forge
#     chardet-3.0.4              |py36h9f0ad1d_1006         188 KB  conda-forge
#     cryptography-2.9.2         |   py36h45558ae_0         613 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     pandas-1.0.4               |   py36h830a2c2_0        10.1 MB  conda-forge
#     pysocks-1.7.1              |   py36h9f0ad1d_1          27 KB  conda-forge
#     toolz-0.10.0               |             py_0          46 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        12.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   altair             conda-forge/noarch::altair-4.1.0-py_1
#   attrs              conda-forge/noarch::attrs-19.3.0-py_0
#   branca             conda-forge/noarch::branca-0.4.1-py_0
#   brotlipy           conda-forge/linux-64::brotlipy-0.7.0-py36h8c4c3a4_1000
#   chardet            conda-forge/linux-64::chardet-3.0.4-py36h9f0ad1d_1006
#   cryptography       conda-forge/linux-64::cryptography-2.9.2-py36h45558ae_0
#   entrypoints        conda-forge/linux-64::entrypoints-0.3-py36h9f0ad1d_1001
#   folium             conda-forge/noarch::folium-0.5.0-py_0
#   idna               conda-forge/noarch::idna-2.9-py_1
#   importlib_metadata conda-forge/noarch::importlib_metadata-1.6.0-0
#   jinja2             conda-forge/noarch::jinja2-2.11.2-pyh9f0ad1d_0
#   jsonschema         conda-forge/linux-64::jsonschema-3.2.0-py36h9f0ad1d_1
#   markupsafe         conda-forge/linux-64::markupsafe-1.1.1-py36h8c4c3a4_1
#   pandas             conda-forge/linux-64::pandas-1.0.4-py36h830a2c2_0
#   pyopenssl          conda-forge/noarch::pyopenssl-19.1.0-py_1
#   pyrsistent         conda-forge/linux-64::pyrsistent-0.16.0-py36h8c4c3a4_0
#   pysocks            conda-forge/linux-64::pysocks-1.7.1-py36h9f0ad1d_1
#   pytz               conda-forge/noarch::pytz-2020.1-pyh9f0ad1d_0
#   requests           conda-forge/noarch::requests-2.23.0-pyh8c360ce_2
#   toolz              conda-forge/noarch::toolz-0.10.0-py_0
#   urllib3            conda-forge/noarch::urllib3-1.25.9-py_0
#   vincent            conda-forge/noarch::vincent-0.4.4-py_1
#
# The following packages will be UPDATED:
#
#   ca-certificates                     2020.4.5.1-hecc5488_0 --> 2020.4.5.2-hecda079_0
#   certifi                         2020.4.5.1-py36h9f0ad1d_0 --> 2020.4.5.2-py36h9f0ad1d_0
#
#
#
# Downloading and Extracting Packages
# certifi-2020.4.5.2   | 152 KB    | ##################################### | 100%
# ca-certificates-2020 | 147 KB    | ##################################### | 100%
# pysocks-1.7.1        | 27 KB     | ##################################### | 100%
# toolz-0.10.0         | 46 KB     | ##################################### | 100%
# chardet-3.0.4        | 188 KB    | ##################################### | 100%
# pandas-1.0.4         | 10.1 MB   | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# branca-0.4.1         | 26 KB     | ##################################### | 100%
# cryptography-2.9.2   | 613 KB    | ##################################### | 100%
# brotlipy-0.7.0       | 346 KB    | ##################################### | 100%
# altair-4.1.0         | 614 KB    | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Libraries imported.

# %%
# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     geopy-1.22.0               |     pyh9f0ad1d_0          63 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:          97 KB
#
# The following NEW packages will be INSTALLED:
#
#   geographiclib      conda-forge/noarch::geographiclib-1.50-py_0
#   geopy              conda-forge/noarch::geopy-1.22.0-pyh9f0ad1d_0
#
#
#
# Downloading and Extracting Packages
# geopy-1.22.0         | 63 KB     | ##################################### | 100%
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
# !pip install lxml
import lxml
# Out:
# Collecting lxml
#   Downloading https://files.pythonhosted.org/packages/55/6f/c87dffdd88a54dd26a3a9fef1d14b6384a9933c455c54ce3ca7d64a84c88/lxml-4.5.1-cp36-cp36m-manylinux1_x86_64.whl (5.5MB)
#      |████████████████████████████████| 5.5MB 6.5MB/s eta 0:00:01
# Installing collected packages: lxml
# Successfully installed lxml-4.5.1

# %%
# !pip install beautifulsoup4
from bs4 import BeautifulSoup
# Out:
# Collecting beautifulsoup4
#   Downloading https://files.pythonhosted.org/packages/66/25/ff030e2437265616a1e9b25ccc864e0371a0bc3adb7c5a404fd661c6f4f6/beautifulsoup4-4.9.1-py3-none-any.whl (115kB)
#      |████████████████████████████████| 122kB 6.5MB/s eta 0:00:01
# Collecting soupsieve>1.2 (from beautifulsoup4)
#   Downloading https://files.pythonhosted.org/packages/6f/8f/457f4a5390eeae1cc3aeab89deb7724c965be841ffca6cfca9197482e470/soupsieve-2.0.1-py3-none-any.whl
# Installing collected packages: soupsieve, beautifulsoup4
# Successfully installed beautifulsoup4-4.9.1 soupsieve-2.0.1

# %% [markdown]
# ### **Import Data Source 1**

# %%
response = requests.get("http://www.healthysf.org/bdi/outcomes/zipmap.htm")
soup = BeautifulSoup(response.text, "lxml")
table = soup.find_all("table")
df = pd.read_html(str(table))
df = pd.DataFrame(df[4])

# %%
df.head()
# Out:
#           0                                        1                         2
# 0  Zip Code                             Neighborhood  Population (Census 2000)
# 1     94102  Hayes Valley/Tenderloin/North of Market                     28991
# 2     94103                          South of Market                     23016
# 3     94107                             Potrero Hill                     17368
# 4     94108                                Chinatown                     13716

# %%
df.columns = df.iloc[0]
df = df.iloc[1:-1, :-1]
sf_data = df
sf_data.head()
# Out:
# 0 Zip Code                             Neighborhood
# 1    94102  Hayes Valley/Tenderloin/North of Market
# 2    94103                          South of Market
# 3    94107                             Potrero Hill
# 4    94108                                Chinatown
# 5    94109             Polk/Russian Hill (Nob Hill)

# %% [markdown]
# ### **Check Data Types**

# %%
sf_data.dtypes
# Out:
# 0
# Zip Code        object
# Neighborhood    object
# dtype: object

# %%
sf_data[["Zip Code"]] = sf_data[["Zip Code"]].astype("int")
sf_data.dtypes
# Out:
# 0
# Zip Code         int64
# Neighborhood    object
# dtype: object

# %% [markdown]
# ### **Import Data Source 2**

# %%
df1=pd.read_csv("http://docs.gaslamp.media/wp-content/uploads/2013/08/zip_codes_states.csv")

# %%
df1.head()
# Out:
#    zip_code   latitude  longitude        city state     county
# 0       501  40.922326 -72.637078  Holtsville    NY    Suffolk
# 1       544  40.922326 -72.637078  Holtsville    NY    Suffolk
# 2       601  18.165273 -66.722583    Adjuntas    PR   Adjuntas
# 3       602  18.393103 -67.180953      Aguada    PR     Aguada
# 4       603  18.455913 -67.145780   Aguadilla    PR  Aguadilla

# %% [markdown]
# ### **Sync the zip code attribute name and merge two dataframes**

# %%
sf_data.rename(columns={'Zip Code':'zipcode'},inplace=True)
sf_data.head()
# Out:
# 0  zipcode                             Neighborhood
# 1    94102  Hayes Valley/Tenderloin/North of Market
# 2    94103                          South of Market
# 3    94107                             Potrero Hill
# 4    94108                                Chinatown
# 5    94109             Polk/Russian Hill (Nob Hill)

# %%
df1.rename(columns={'zip_code':'zipcode'},inplace=True)
df1.head()
# Out:
#    zipcode   latitude  longitude        city state     county
# 0      501  40.922326 -72.637078  Holtsville    NY    Suffolk
# 1      544  40.922326 -72.637078  Holtsville    NY    Suffolk
# 2      601  18.165273 -66.722583    Adjuntas    PR   Adjuntas
# 3      602  18.393103 -67.180953      Aguada    PR     Aguada
# 4      603  18.455913 -67.145780   Aguadilla    PR  Aguadilla

# %%
df2 = pd.merge(sf_data, df1, on='zipcode')
df2
# Out:
#     zipcode                             Neighborhood   latitude   longitude  \
# 0     94102  Hayes Valley/Tenderloin/North of Market  37.779278 -122.416582
# 1     94103                          South of Market  37.775678 -122.412131
# 2     94107                             Potrero Hill  37.769029 -122.393681
# 3     94108                                Chinatown  37.791028 -122.408782
# 4     94109             Polk/Russian Hill (Nob Hill)  37.795219 -122.420782
# 5     94110             Inner Mission/Bernal Heights  37.748932 -122.416281
# 6     94112       Ingelside-Excelsior/Crocker-Amazon  37.721981 -122.439382
# 7     94114                        Castro/Noe Valley  37.758279 -122.439332
# 8     94115               Western Addition/Japantown  37.786028 -122.437032
# 9     94116                     Parkside/Forest Hill  37.743857 -122.483232
# 10    94117                           Haight-Ashbury  37.769079 -122.443882
# 11    94118                           Inner Richmond  37.778779 -122.459982
# 12    94121                           Outer Richmond  37.777129 -122.491682
# 13    94122                                   Sunset  37.761179 -122.475732
# 14    94123                                   Marina  37.799670 -122.435732
# 15    94124                    Bayview-Hunters Point  37.731230 -122.382857
# 16    94127    St. Francis Wood/Miraloma/West Portal  37.734030 -122.458632
# 17    94131                     Twin Peaks-Glen Park  37.743630 -122.443182
# 18    94132                              Lake Merced  37.722631 -122.482483
# 19    94133                    North Beach/Chinatown  37.801928 -122.410182
# 20    94134              Visitacion Valley/Sunnydale  37.721680 -122.410832
#
#              city state         county
# 0   San Francisco    CA  San Francisco
# 1   San Francisco    CA  San Francisco
# 2   San Francisco    CA  San Francisco
# 3   San Francisco    CA  San Francisco
# 4   San Francisco    CA  San Francisco
# 5   San Francisco    CA  San Francisco
# 6   San Francisco    CA  San Francisco
# 7   San Francisco    CA  San Francisco
# 8   San Francisco    CA  San Francisco
# 9   San Francisco    CA  San Francisco
# 10  San Francisco    CA  San Francisco
# 11  San Francisco    CA  San Francisco
# 12  San Francisco    CA  San Francisco
# 13  San Francisco    CA  San Francisco
# 14  San Francisco    CA  San Francisco
# 15  San Francisco    CA  San Francisco
# 16  San Francisco    CA  San Francisco
# 17  San Francisco    CA  San Francisco
# 18  San Francisco    CA  San Francisco
# 19  San Francisco    CA  San Francisco
# 20  San Francisco    CA  San Francisco

# %%
df2.dtypes
# Out:
# zipcode           int64
# Neighborhood     object
# latitude        float64
# longitude       float64
# city             object
# state            object
# county           object
# dtype: object

# %% [markdown]
# ### **Get the geographical coordinates of San Francisco**

# %%
address = 'San Francisco'

geolocator = Nominatim(user_agent="San Francisco_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of sf are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of sf are 37.7790262, -122.4199061.

# %%
# create map of San Francisco using latitude and longitude values
map_sf = folium.Map(location=[latitude, longitude], zoom_start=12)
map_sf
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### **San Francisco Neighborhood Visualization**

# %%
# add markers to map
for lat, lng, neighborhood in zip(df2['latitude'], df2['longitude'], df2['Neighborhood']):
    label = '{}'.format(neighborhood)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_sf)  
    
map_sf
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### **Use Foursquare API to explore the neighborhood**

# %%
CLIENT_ID = 'MQ0XTFBCXWHDMFW1ZMX5USNUVLP0UTEJXXILK0HSAIWXPO4K' # your Foursquare ID
CLIENT_SECRET = 'QM5UVPK4MFFXQGBQM451YO3HMO1G1L4Z2FOOIESN3JOZS5KF' # your Foursquare Secret
VERSION = '20180604'

# %%
def getNearbyVenues(Neighborhood, latitudes, longitudes):
    radius=500
    LIMIT=100
    venues_list=[]
    for lat, lng, neighborhood in zip(df2['latitude'], df2['longitude'], df2['Neighborhood']):
        print(neighborhood)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            neighborhood, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
sf_venues = getNearbyVenues(Neighborhood=df2['Neighborhood'],
                                   latitudes=df2['latitude'],
                                   longitudes=df2['longitude']
                                  )
# Out:
# Hayes Valley/Tenderloin/North of Market
# South of Market
# Potrero Hill
# Chinatown
# Polk/Russian Hill (Nob Hill)
# Inner Mission/Bernal Heights
# Ingelside-Excelsior/Crocker-Amazon
# Castro/Noe Valley
# Western Addition/Japantown
# Parkside/Forest Hill
# Haight-Ashbury
# Inner Richmond
# Outer Richmond
# Sunset
# Marina
# Bayview-Hunters Point
# St. Francis Wood/Miraloma/West Portal
# Twin Peaks-Glen Park
# Lake Merced
# North Beach/Chinatown
# Visitacion Valley/Sunnydale

# %%
sf_venues.head()
# Out:
#                               Neighborhood  Neighborhood Latitude  \
# 0  Hayes Valley/Tenderloin/North of Market              37.779278
# 1  Hayes Valley/Tenderloin/North of Market              37.779278
# 2  Hayes Valley/Tenderloin/North of Market              37.779278
# 3  Hayes Valley/Tenderloin/North of Market              37.779278
# 4  Hayes Valley/Tenderloin/North of Market              37.779278
#
#    Neighborhood Longitude             Venue  Venue Latitude  Venue Longitude  \
# 0             -122.416582  Asian Art Museum       37.780178      -122.416505
# 1             -122.416582   Orpheum Theatre       37.779315      -122.414790
# 2             -122.416582      Philz Coffee       37.781266      -122.416901
# 3             -122.416582      Ananda Fuara       37.777693      -122.416353
# 4             -122.416582        The Strand       37.779888      -122.413138
#
#                   Venue Category
# 0                     Art Museum
# 1                        Theater
# 2                    Coffee Shop
# 3  Vegetarian / Vegan Restaurant
# 4                        Theater

# %%
sf_venues.shape
# Out:
# (1059, 7)

# %%
sf_top10=sf_venues['Venue Category'].value_counts().nlargest(10).to_frame(name='Frequency')
sf_top10=sf_top10.reset_index()
sf_top10.rename(index=str, columns={"index": "Venue_Category", "frequency": "Frequency"}, inplace=True)
sf_top10
# Out:
#        Venue_Category  Frequency
# 0         Coffee Shop         46
# 1         Pizza Place         33
# 2                Café         30
# 3                Park         24
# 4  Chinese Restaurant         23
# 5              Bakery         23
# 6  Italian Restaurant         23
# 7    Sushi Restaurant         20
# 8       Deli / Bodega         19
# 9                 Bar         18

# %%
import seaborn as sns
from matplotlib import pyplot as plt

s=sns.barplot(x="Venue_Category", y="Frequency", data=sf_top10)
s.set_xticklabels(s.get_xticklabels(), rotation=45, horizontalalignment='right')

plt.title('10 Most Frequently Occuring Venues in San Francisco', fontsize=15)
plt.xlabel("Venue Category", fontsize=15)
plt.ylabel ("Frequency", fontsize=15)
plt.savefig("Most_Freq_Venues1.png", dpi=300)
fig = plt.figure(figsize=(18,7))
plt.show()

# %% [markdown]
# #### **Top 5 Neighborhood for Coffee Shop in San Francisco**

# %%
sf_coffee = sf_venues[sf_venues['Venue Category'].str.contains('Coffee Shop')].reset_index(drop=True)
sf_coffee5=sf_coffee['Neighborhood'].value_counts()
sf_coffee5
# Out:
# North Beach/Chinatown                      7
# South of Market                            7
# Hayes Valley/Tenderloin/North of Market    5
# Polk/Russian Hill (Nob Hill)               5
# Chinatown                                  4
# Inner Mission/Bernal Heights               3
# Potrero Hill                               3
# Sunset                                     3
# Inner Richmond                             2
# Castro/Noe Valley                          2
# Haight-Ashbury                             1
# Ingelside-Excelsior/Crocker-Amazon         1
# Marina                                     1
# Lake Merced                                1
# Twin Peaks-Glen Park                       1
# Name: Neighborhood, dtype: int64

# %%
sf_coffee6=sf_coffee5.nlargest(5).to_frame(name='Frequency')
sf_coffee6=sf_coffee6.reset_index()
sf_coffee6.rename(index=str, columns={"index": "Neighborhood", "frequency": "Frequency"}, inplace=True)
sf_coffee6
# Out:
#                               Neighborhood  Frequency
# 0                    North Beach/Chinatown          7
# 1                          South of Market          7
# 2  Hayes Valley/Tenderloin/North of Market          5
# 3             Polk/Russian Hill (Nob Hill)          5
# 4                                Chinatown          4

# %%
s=sns.barplot(x="Neighborhood", y="Frequency", data=sf_coffee6)
s.set_xticklabels(s.get_xticklabels(), rotation=45, horizontalalignment='right')

plt.title('Top 5 Neighborhoods for Coffee Shop in San Francisco', fontsize=15)
plt.xlabel("Neighborhood", fontsize=15)
plt.ylabel ("Frequency", fontsize=15)
plt.savefig("Most_Freq_Venues4.png", dpi=300)
fig = plt.figure(figsize=(18,7))
plt.show()

# %% [markdown]
# #### **Top 5 Neighborhood for Cafe in San Francisco**

# %%
sf_cafe = sf_venues[sf_venues['Venue Category'].str.contains('Café')].reset_index(drop=True)
sf_cafe1= sf_cafe['Neighborhood'].value_counts()
sf_cafe1
# Out:
# North Beach/Chinatown                      6
# Outer Richmond                             3
# Hayes Valley/Tenderloin/North of Market    3
# South of Market                            3
# Chinatown                                  3
# Western Addition/Japantown                 3
# Parkside/Forest Hill                       3
# Inner Richmond                             2
# Polk/Russian Hill (Nob Hill)               1
# Potrero Hill                               1
# Castro/Noe Valley                          1
# Lake Merced                                1
# Name: Neighborhood, dtype: int64

# %%
sf_cafe2=sf_cafe1.nlargest(5).to_frame(name='Frequency')
sf_cafe2=sf_cafe2.reset_index()
sf_cafe2.rename(index=str, columns={"index": "Neighborhood", "frequency": "Frequency"}, inplace=True)
sf_cafe2
# Out:
#                               Neighborhood  Frequency
# 0                    North Beach/Chinatown          6
# 1                           Outer Richmond          3
# 2  Hayes Valley/Tenderloin/North of Market          3
# 3                          South of Market          3
# 4                                Chinatown          3

# %%
s=sns.barplot(x="Neighborhood", y="Frequency", data=sf_cafe2)
s.set_xticklabels(s.get_xticklabels(), rotation=45, horizontalalignment='right')

plt.title('Top 5 Neighborhoods for Café in San Francisco', fontsize=15)
plt.xlabel("Neighborhood", fontsize=15)
plt.ylabel ("Frequency", fontsize=15)
plt.savefig("Most_Freq_Venues4.png", dpi=300)
fig = plt.figure(figsize=(18,7))
plt.show()

# %% [markdown]
# #### **Top 5 Neighborhood for Pizza in San Francisco**

# %%
sf_pizza = sf_venues[sf_venues['Venue Category'].str.contains('Pizza Place')].reset_index(drop=True)
sf_pizza1=sf_pizza['Neighborhood'].value_counts()
sf_pizza1
# Out:
# North Beach/Chinatown                 7
# Inner Richmond                        5
# Western Addition/Japantown            3
# Inner Mission/Bernal Heights          3
# Outer Richmond                        3
# Ingelside-Excelsior/Crocker-Amazon    2
# Parkside/Forest Hill                  2
# Polk/Russian Hill (Nob Hill)          2
# Haight-Ashbury                        1
# Marina                                1
# Chinatown                             1
# Sunset                                1
# South of Market                       1
# Lake Merced                           1
# Name: Neighborhood, dtype: int64

# %%
sf_pizza2=sf_pizza1.nlargest(5).to_frame(name='Frequency')
sf_pizza2=sf_pizza2.reset_index()
sf_pizza2.rename(index=str, columns={"index": "Neighborhood", "frequency": "Frequency"}, inplace=True)
sf_pizza2
# Out:
#                    Neighborhood  Frequency
# 0         North Beach/Chinatown          7
# 1                Inner Richmond          5
# 2    Western Addition/Japantown          3
# 3  Inner Mission/Bernal Heights          3
# 4                Outer Richmond          3

# %%
s=sns.barplot(x="Neighborhood", y="Frequency", data=sf_pizza2)
s.set_xticklabels(s.get_xticklabels(), rotation=45, horizontalalignment='right')

plt.title('Top 5 Neighborhoods for Café in San Francisco', fontsize=15)
plt.xlabel("Neighborhood", fontsize=15)
plt.ylabel ("Frequency", fontsize=15)
plt.savefig("Most_Freq_Venues4.png", dpi=300)
fig = plt.figure(figsize=(18,7))
plt.show()

# %%
sf_group=sf_venues.groupby('Neighborhood').count()
sf_group
sf_group=sf_group.reset_index()
sf_group.rename(index=str, columns={"Neighborhood": "Neighborhood", "Neighborhood Latitude": "Neighborhood Latitude","Neighborhood Longitude":"Neighborhood Longitude",\
                                  "Venue":"Venue","Venue Latitude":"Venue Latitude","Venue Longitude":"Venue Longitude","Venue Category":"Venue Category" }, inplace=True)
sf_group
# Out:
#                                Neighborhood  Neighborhood Latitude  \
# 0                         Castro/Noe Valley                     42
# 1                                 Chinatown                     82
# 2                            Haight-Ashbury                     38
# 3   Hayes Valley/Tenderloin/North of Market                     72
# 4        Ingelside-Excelsior/Crocker-Amazon                     36
# 5              Inner Mission/Bernal Heights                     49
# 6                            Inner Richmond                     80
# 7                               Lake Merced                     16
# 8                                    Marina                    100
# 9                     North Beach/Chinatown                     93
# 10                           Outer Richmond                     33
# 11                     Parkside/Forest Hill                     44
# 12             Polk/Russian Hill (Nob Hill)                     76
# 13                             Potrero Hill                     37
# 14                          South of Market                    100
# 15    St. Francis Wood/Miraloma/West Portal                      3
# 16                                   Sunset                     38
# 17                     Twin Peaks-Glen Park                     18
# 18              Visitacion Valley/Sunnydale                      2
# 19               Western Addition/Japantown                    100
#
#     Neighborhood Longitude  Venue  Venue Latitude  Venue Longitude  \
# 0                       42     42              42               42
# 1                       82     82              82               82
# 2                       38     38              38               38
# 3                       72     72              72               72
# 4                       36     36              36               36
# 5                       49     49              49               49
# 6                       80     80              80               80
# 7                       16     16              16               16
# 8                      100    100             100              100
# 9                       93     93              93               93
# 10                      33     33              33               33
# 11                      44     44              44               44
# 12                      76     76              76               76
# 13                      37     37              37               37
# 14                     100    100             100              100
# 15                       3      3               3                3
# 16                      38     38              38               38
# 17                      18     18              18               18
# 18                       2      2               2                2
# 19                     100    100             100              100
#
#     Venue Category
# 0               42
# 1               82
# 2               38
# 3               72
# 4               36
# 5               49
# 6               80
# 7               16
# 8              100
# 9               93
# 10              33
# 11              44
# 12              76
# 13              37
# 14             100
# 15               3
# 16              38
# 17              18
# 18               2
# 19             100

# %%
sf_group.shape
# Out:
# (20, 7)

# %%
sf_group.sort_values(by=['Venue Category'],ascending=False)
# Out:
#                                Neighborhood  Neighborhood Latitude  \
# 19               Western Addition/Japantown                    100
# 14                          South of Market                    100
# 8                                    Marina                    100
# 9                     North Beach/Chinatown                     93
# 1                                 Chinatown                     82
# 6                            Inner Richmond                     80
# 12             Polk/Russian Hill (Nob Hill)                     76
# 3   Hayes Valley/Tenderloin/North of Market                     72
# 5              Inner Mission/Bernal Heights                     49
# 11                     Parkside/Forest Hill                     44
# 0                         Castro/Noe Valley                     42
# 2                            Haight-Ashbury                     38
# 16                                   Sunset                     38
# 13                             Potrero Hill                     37
# 4        Ingelside-Excelsior/Crocker-Amazon                     36
# 10                           Outer Richmond                     33
# 17                     Twin Peaks-Glen Park                     18
# 7                               Lake Merced                     16
# 15    St. Francis Wood/Miraloma/West Portal                      3
# 18              Visitacion Valley/Sunnydale                      2
#
#     Neighborhood Longitude  Venue  Venue Latitude  Venue Longitude  \
# 19                     100    100             100              100
# 14                     100    100             100              100
# 8                      100    100             100              100
# 9                       93     93              93               93
# 1                       82     82              82               82
# 6                       80     80              80               80
# 12                      76     76              76               76
# 3                       72     72              72               72
# 5                       49     49              49               49
# 11                      44     44              44               44
# 0                       42     42              42               42
# 2                       38     38              38               38
# 16                      38     38              38               38
# 13                      37     37              37               37
# 4                       36     36              36               36
# 10                      33     33              33               33
# 17                      18     18              18               18
# 7                       16     16              16               16
# 15                       3      3               3                3
# 18                       2      2               2                2
#
#     Venue Category
# 19             100
# 14             100
# 8              100
# 9               93
# 1               82
# 6               80
# 12              76
# 3               72
# 5               49
# 11              44
# 0               42
# 2               38
# 16              38
# 13              37
# 4               36
# 10              33
# 17              18
# 7               16
# 15               3
# 18               2

# %%
sf_mostvisit5 = pd.DataFrame({
    'Neighborhood': ['Western Addition/Japantown', 'South of Market', 'Marina','North Beach/Chinatown', 'Chinatown'],
    'Frequency': [100, 100, 100, 93, 82]
})
sf_mostvisit5
# Out:
#                  Neighborhood  Frequency
# 0  Western Addition/Japantown        100
# 1             South of Market        100
# 2                      Marina        100
# 3       North Beach/Chinatown         93
# 4                   Chinatown         82

# %%
import seaborn as sns
from matplotlib import pyplot as plt

s=sns.barplot(x="Neighborhood", y="Frequency", data=sf_mostvisit5)
s.set_xticklabels(s.get_xticklabels(), rotation=45, horizontalalignment='right')

plt.title('5 Most Frequently Occuring Neighborhoods in San Francisco', fontsize=15)
plt.xlabel("Venue Category", fontsize=15)
plt.ylabel ("Frequency", fontsize=15)
plt.savefig("Most_Freq_Venues1.png", dpi=300)
fig = plt.figure(figsize=(18,7))
plt.show()

# %% [markdown]
# ### **Explore the Restaurants in San Francisco**

# %%
# Create a Data-Frame out of it to Concentrate Only on Restaurants 
sf_restaurant = sf_venues[sf_venues['Venue Category'].str.contains('Restaurant')].reset_index(drop=True)
sf_restaurant.index = np.arange(1, len(sf_restaurant )+1)

# %%
print (sf_restaurant['Venue Category'].value_counts().nlargest(10))
# Out:
# Chinese Restaurant         23
# Italian Restaurant         23
# Sushi Restaurant           20
# Vietnamese Restaurant      15
# American Restaurant        15
# Mexican Restaurant         14
# Restaurant                 11
# Thai Restaurant            10
# Japanese Restaurant        10
# New American Restaurant     8
# Name: Venue Category, dtype: int64

# %%
sf_res10=sf_restaurant['Venue Category'].value_counts().nlargest(10).to_frame(name='Frequency')
sf_res10=sf_res10.reset_index()
sf_res10.rename(index=str, columns={"index": "Venue_Category", "frequency": "Frequency"}, inplace=True)
sf_res10
# Out:
#             Venue_Category  Frequency
# 0       Chinese Restaurant         23
# 1       Italian Restaurant         23
# 2         Sushi Restaurant         20
# 3    Vietnamese Restaurant         15
# 4      American Restaurant         15
# 5       Mexican Restaurant         14
# 6               Restaurant         11
# 7          Thai Restaurant         10
# 8      Japanese Restaurant         10
# 9  New American Restaurant          8

# %%
s=sns.barplot(x="Venue_Category", y="Frequency", data=sf_res10)
s.set_xticklabels(s.get_xticklabels(), rotation=45, horizontalalignment='right')

plt.title('10 Most Frequently Occuring Restaurants in San Francisco', fontsize=15)
plt.xlabel("Venue Category", fontsize=15)
plt.ylabel ("Frequency", fontsize=15)
plt.savefig("Most_Freq_Venues2.png", dpi=300)
fig = plt.figure(figsize=(18,7))
plt.show()

# %%
sf_restaurant.head()
# Out:
#                               Neighborhood  Neighborhood Latitude  \
# 1  Hayes Valley/Tenderloin/North of Market              37.779278
# 2  Hayes Valley/Tenderloin/North of Market              37.779278
# 3  Hayes Valley/Tenderloin/North of Market              37.779278
# 4  Hayes Valley/Tenderloin/North of Market              37.779278
# 5  Hayes Valley/Tenderloin/North of Market              37.779278
#
#    Neighborhood Longitude                 Venue  Venue Latitude  \
# 1             -122.416582          Ananda Fuara       37.777693
# 2             -122.416582      Golden Era Vegan       37.781495
# 3             -122.416582  Morty's Delicatessen       37.781710
# 4             -122.416582                Villon       37.780865
# 5             -122.416582             Azalina's       37.776370
#
#    Venue Longitude                 Venue Category
# 1      -122.416353  Vegetarian / Vegan Restaurant
# 2      -122.416822  Vegetarian / Vegan Restaurant
# 3      -122.415243            American Restaurant
# 4      -122.412471              French Restaurant
# 5      -122.416945               Malay Restaurant

# %%
# one hot encoding
sf_onehot = pd.get_dummies(sf_restaurant[['Venue Category']], prefix="", prefix_sep="")
sf_onehot.insert(loc=0, column='Neighborhood', value=sf_restaurant['Neighborhood'] )
sf_onehot.shape
# Out:
# (241, 47)

# %%
sf_grouped = sf_onehot.groupby('Neighborhood').mean().reset_index()
sf_grouped
# Out:
#                                Neighborhood  African Restaurant  \
# 0                         Castro/Noe Valley            0.000000
# 1                                 Chinatown            0.000000
# 2                            Haight-Ashbury            0.000000
# 3   Hayes Valley/Tenderloin/North of Market            0.000000
# 4        Ingelside-Excelsior/Crocker-Amazon            0.000000
# 5              Inner Mission/Bernal Heights            0.000000
# 6                            Inner Richmond            0.000000
# 7                               Lake Merced            0.000000
# 8                                    Marina            0.000000
# 9                     North Beach/Chinatown            0.000000
# 10                           Outer Richmond            0.000000
# 11                     Parkside/Forest Hill            0.000000
# 12             Polk/Russian Hill (Nob Hill)            0.047619
# 13                             Potrero Hill            0.000000
# 14                          South of Market            0.000000
# 15                                   Sunset            0.000000
# 16                     Twin Peaks-Glen Park            0.000000
# 17               Western Addition/Japantown            0.000000
#
#     American Restaurant  Asian Restaurant  Burmese Restaurant  \
# 0              0.166667          0.000000            0.000000
# 1              0.142857          0.000000            0.000000
# 2              0.000000          0.000000            0.000000
# 3              0.153846          0.076923            0.000000
# 4              0.000000          0.000000            0.000000
# 5              0.100000          0.000000            0.000000
# 6              0.000000          0.000000            0.068966
# 7              0.000000          0.000000            0.000000
# 8              0.074074          0.037037            0.000000
# 9              0.000000          0.047619            0.000000
# 10             0.111111          0.000000            0.000000
# 11             0.066667          0.000000            0.000000
# 12             0.095238          0.000000            0.000000
# 13             0.000000          0.000000            0.000000
# 14             0.000000          0.000000            0.000000
# 15             0.000000          0.000000            0.000000
# 16             0.000000          0.000000            0.000000
# 17             0.086957          0.086957            0.000000
#
#     Cantonese Restaurant  Caribbean Restaurant  Chinese Restaurant  \
# 0               0.000000              0.000000            0.000000
# 1               0.095238              0.000000            0.047619
# 2               0.000000              0.000000            0.000000
# 3               0.000000              0.000000            0.000000
# 4               0.000000              0.000000            0.142857
# 5               0.000000              0.000000            0.100000
# 6               0.000000              0.000000            0.206897
# 7               0.000000              0.000000            0.000000
# 8               0.000000              0.037037            0.000000
# 9               0.000000              0.000000            0.190476
# 10              0.000000              0.000000            0.222222
# 11              0.000000              0.000000            0.333333
# 12              0.000000              0.000000            0.000000
# 13              0.000000              0.000000            0.000000
# 14              0.000000              0.000000            0.000000
# 15              0.000000              0.000000            0.071429
# 16              0.000000              0.000000            0.000000
# 17              0.000000              0.000000            0.043478
#
#     Dim Sum Restaurant  Dumpling Restaurant  Ethiopian Restaurant  \
# 0             0.000000             0.000000              0.000000
# 1             0.047619             0.000000              0.000000
# 2             0.000000             0.000000              0.000000
# 3             0.000000             0.000000              0.000000
# 4             0.000000             0.000000              0.000000
# 5             0.000000             0.000000              0.000000
# 6             0.000000             0.000000              0.000000
# 7             0.000000             0.000000              0.000000
# 8             0.000000             0.000000              0.000000
# 9             0.000000             0.000000              0.000000
# 10            0.000000             0.000000              0.000000
# 11            0.000000             0.200000              0.000000
# 12            0.000000             0.000000              0.000000
# 13            0.000000             0.500000              0.000000
# 14            0.000000             0.000000              0.076923
# 15            0.071429             0.071429              0.000000
# 16            1.000000             0.000000              0.000000
# 17            0.000000             0.000000              0.000000
#
#     Fast Food Restaurant  Filipino Restaurant  French Restaurant  \
# 0               0.000000             0.000000           0.000000
# 1               0.000000             0.000000           0.000000
# 2               0.000000             0.000000           0.000000
# 3               0.000000             0.000000           0.076923
# 4               0.071429             0.071429           0.000000
# 5               0.000000             0.000000           0.000000
# 6               0.068966             0.000000           0.034483
# 7               0.000000             0.000000           0.000000
# 8               0.000000             0.000000           0.148148
# 9               0.000000             0.000000           0.000000
# 10              0.000000             0.000000           0.000000
# 11              0.000000             0.000000           0.000000
# 12              0.000000             0.000000           0.047619
# 13              0.000000             0.000000           0.000000
# 14              0.000000             0.000000           0.000000
# 15              0.000000             0.000000           0.000000
# 16              0.000000             0.000000           0.000000
# 17              0.000000             0.000000           0.000000
#
#     Greek Restaurant  Hotpot Restaurant  Hunan Restaurant  Indian Restaurant  \
# 0           0.000000           0.000000          0.000000           0.000000
# 1           0.000000           0.000000          0.047619           0.000000
# 2           0.000000           0.000000          0.000000           0.000000
# 3           0.000000           0.000000          0.000000           0.000000
# 4           0.000000           0.000000          0.071429           0.000000
# 5           0.000000           0.000000          0.000000           0.100000
# 6           0.000000           0.000000          0.000000           0.034483
# 7           0.000000           0.000000          0.000000           0.000000
# 8           0.037037           0.037037          0.000000           0.000000
# 9           0.000000           0.000000          0.000000           0.047619
# 10          0.000000           0.000000          0.000000           0.000000
# 11          0.000000           0.000000          0.000000           0.000000
# 12          0.000000           0.000000          0.000000           0.000000
# 13          0.000000           0.000000          0.000000           0.000000
# 14          0.000000           0.000000          0.000000           0.000000
# 15          0.000000           0.071429          0.000000           0.071429
# 16          0.000000           0.000000          0.000000           0.000000
# 17          0.000000           0.000000          0.000000           0.043478
#
#     Italian Restaurant  Japanese Curry Restaurant  Japanese Restaurant  \
# 0             0.000000                   0.000000             0.166667
# 1             0.142857                   0.047619             0.000000
# 2             0.000000                   0.000000             0.000000
# 3             0.000000                   0.000000             0.000000
# 4             0.000000                   0.000000             0.071429
# 5             0.000000                   0.000000             0.000000
# 6             0.068966                   0.000000             0.103448
# 7             0.000000                   0.000000             0.000000
# 8             0.148148                   0.000000             0.000000
# 9             0.285714                   0.000000             0.000000
# 10            0.000000                   0.000000             0.222222
# 11            0.066667                   0.000000             0.066667
# 12            0.190476                   0.000000             0.000000
# 13            0.000000                   0.000000             0.000000
# 14            0.076923                   0.000000             0.000000
# 15            0.000000                   0.000000             0.071429
# 16            0.000000                   0.000000             0.000000
# 17            0.086957                   0.000000             0.043478
#
#     Jewish Restaurant  Korean Restaurant  Latin American Restaurant  \
# 0                 0.0           0.000000                   0.000000
# 1                 0.0           0.047619                   0.000000
# 2                 0.0           0.000000                   0.000000
# 3                 0.0           0.000000                   0.000000
# 4                 0.0           0.000000                   0.142857
# 5                 0.1           0.000000                   0.000000
# 6                 0.0           0.103448                   0.000000
# 7                 0.0           0.000000                   0.000000
# 8                 0.0           0.000000                   0.000000
# 9                 0.0           0.000000                   0.047619
# 10                0.0           0.000000                   0.000000
# 11                0.0           0.066667                   0.000000
# 12                0.0           0.047619                   0.000000
# 13                0.0           0.000000                   0.000000
# 14                0.0           0.000000                   0.000000
# 15                0.0           0.000000                   0.000000
# 16                0.0           0.000000                   0.000000
# 17                0.0           0.000000                   0.000000
#
#     Malay Restaurant  Mediterranean Restaurant  Mexican Restaurant  \
# 0           0.000000                  0.000000            0.000000
# 1           0.000000                  0.047619            0.000000
# 2           0.000000                  0.000000            0.000000
# 3           0.076923                  0.000000            0.076923
# 4           0.000000                  0.000000            0.142857
# 5           0.000000                  0.000000            0.200000
# 6           0.000000                  0.000000            0.034483
# 7           0.000000                  0.000000            1.000000
# 8           0.000000                  0.000000            0.111111
# 9           0.000000                  0.047619            0.095238
# 10          0.000000                  0.000000            0.000000
# 11          0.000000                  0.000000            0.000000
# 12          0.000000                  0.047619            0.000000
# 13          0.000000                  0.500000            0.000000
# 14          0.076923                  0.000000            0.076923
# 15          0.000000                  0.000000            0.000000
# 16          0.000000                  0.000000            0.000000
# 17          0.000000                  0.043478            0.043478
#
#     Middle Eastern Restaurant  Modern European Restaurant  \
# 0                    0.000000                    0.000000
# 1                    0.000000                    0.000000
# 2                    0.000000                    0.000000
# 3                    0.000000                    0.000000
# 4                    0.000000                    0.000000
# 5                    0.100000                    0.000000
# 6                    0.000000                    0.000000
# 7                    0.000000                    0.000000
# 8                    0.000000                    0.000000
# 9                    0.000000                    0.000000
# 10                   0.000000                    0.000000
# 11                   0.000000                    0.000000
# 12                   0.000000                    0.047619
# 13                   0.000000                    0.000000
# 14                   0.000000                    0.000000
# 15                   0.071429                    0.000000
# 16                   0.000000                    0.000000
# 17                   0.000000                    0.000000
#
#     New American Restaurant  Ramen Restaurant  Restaurant  Russian Restaurant  \
# 0                  0.000000          0.000000    0.000000            0.000000
# 1                  0.000000          0.000000    0.047619            0.047619
# 2                  0.000000          0.000000    0.000000            0.000000
# 3                  0.000000          0.000000    0.076923            0.000000
# 4                  0.000000          0.000000    0.071429            0.000000
# 5                  0.200000          0.000000    0.000000            0.000000
# 6                  0.000000          0.000000    0.000000            0.000000
# 7                  0.000000          0.000000    0.000000            0.000000
# 8                  0.037037          0.000000    0.000000            0.000000
# 9                  0.047619          0.000000    0.047619            0.000000
# 10                 0.111111          0.111111    0.000000            0.000000
# 11                 0.000000          0.000000    0.000000            0.000000
# 12                 0.047619          0.000000    0.047619            0.000000
# 13                 0.000000          0.000000    0.000000            0.000000
# 14                 0.000000          0.000000    0.307692            0.000000
# 15                 0.000000          0.000000    0.071429            0.000000
# 16                 0.000000          0.000000    0.000000            0.000000
# 17                 0.086957          0.043478    0.043478            0.000000
#
#     Scandinavian Restaurant  Seafood Restaurant  Shanghai Restaurant  \
# 0                  0.000000            0.166667             0.000000
# 1                  0.000000            0.000000             0.000000
# 2                  0.000000            0.000000             0.000000
# 3                  0.076923            0.000000             0.000000
# 4                  0.000000            0.000000             0.000000
# 5                  0.000000            0.000000             0.000000
# 6                  0.000000            0.000000             0.034483
# 7                  0.000000            0.000000             0.000000
# 8                  0.000000            0.037037             0.000000
# 9                  0.000000            0.047619             0.000000
# 10                 0.000000            0.111111             0.000000
# 11                 0.000000            0.000000             0.000000
# 12                 0.000000            0.047619             0.000000
# 13                 0.000000            0.000000             0.000000
# 14                 0.000000            0.000000             0.000000
# 15                 0.000000            0.000000             0.000000
# 16                 0.000000            0.000000             0.000000
# 17                 0.000000            0.043478             0.000000
#
#     South American Restaurant  Southern / Soul Food Restaurant  \
# 0                         0.0                         0.000000
# 1                         0.0                         0.000000
# 2                         0.0                         0.000000
# 3                         0.0                         0.076923
# 4                         0.0                         0.000000
# 5                         0.1                         0.000000
# 6                         0.0                         0.034483
# 7                         0.0                         0.000000
# 8                         0.0                         0.000000
# 9                         0.0                         0.000000
# 10                        0.0                         0.000000
# 11                        0.0                         0.000000
# 12                        0.0                         0.000000
# 13                        0.0                         0.000000
# 14                        0.0                         0.000000
# 15                        0.0                         0.000000
# 16                        0.0                         0.000000
# 17                        0.0                         0.000000
#
#     Spanish Restaurant  Sushi Restaurant  Swiss Restaurant  \
# 0             0.000000          0.000000          0.000000
# 1             0.000000          0.142857          0.000000
# 2             0.000000          0.000000          0.000000
# 3             0.000000          0.000000          0.000000
# 4             0.000000          0.000000          0.000000
# 5             0.000000          0.000000          0.000000
# 6             0.000000          0.137931          0.000000
# 7             0.000000          0.000000          0.000000
# 8             0.037037          0.074074          0.000000
# 9             0.000000          0.095238          0.000000
# 10            0.000000          0.000000          0.000000
# 11            0.000000          0.066667          0.000000
# 12            0.000000          0.190476          0.047619
# 13            0.000000          0.000000          0.000000
# 14            0.000000          0.076923          0.000000
# 15            0.000000          0.071429          0.000000
# 16            0.000000          0.000000          0.000000
# 17            0.000000          0.086957          0.000000
#
#     Szechuan Restaurant  Thai Restaurant  Turkish Restaurant  Udon Restaurant  \
# 0              0.166667         0.333333            0.000000         0.000000
# 1              0.000000         0.000000            0.000000         0.000000
# 2              0.000000         0.000000            0.000000         0.000000
# 3              0.076923         0.000000            0.000000         0.000000
# 4              0.000000         0.071429            0.000000         0.000000
# 5              0.000000         0.000000            0.000000         0.000000
# 6              0.000000         0.034483            0.000000         0.000000
# 7              0.000000         0.000000            0.000000         0.000000
# 8              0.000000         0.074074            0.000000         0.000000
# 9              0.000000         0.000000            0.000000         0.000000
# 10             0.000000         0.000000            0.000000         0.000000
# 11             0.000000         0.066667            0.000000         0.000000
# 12             0.000000         0.000000            0.000000         0.000000
# 13             0.000000         0.000000            0.000000         0.000000
# 14             0.076923         0.153846            0.000000         0.000000
# 15             0.142857         0.000000            0.000000         0.000000
# 16             0.000000         0.000000            0.000000         0.000000
# 17             0.000000         0.043478            0.043478         0.043478
#
#     Vegetarian / Vegan Restaurant  Vietnamese Restaurant
# 0                        0.000000               0.000000
# 1                        0.047619               0.047619
# 2                        1.000000               0.000000
# 3                        0.153846               0.076923
# 4                        0.000000               0.142857
# 5                        0.000000               0.000000
# 6                        0.000000               0.034483
# 7                        0.000000               0.000000
# 8                        0.074074               0.037037
# 9                        0.000000               0.000000
# 10                       0.000000               0.111111
# 11                       0.000000               0.066667
# 12                       0.000000               0.095238
# 13                       0.000000               0.000000
# 14                       0.076923               0.000000
# 15                       0.000000               0.214286
# 16                       0.000000               0.000000
# 17                       0.000000               0.086957

# %% [markdown]
# #### **Output each neighborhood along with the top 5 most common restuarants**

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 5

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = sf_grouped['Neighborhood']

for ind in np.arange(sf_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(sf_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted
# Out:
#                                Neighborhood          1st Most Common Venue  \
# 0                         Castro/Noe Valley                Thai Restaurant
# 1                                 Chinatown            American Restaurant
# 2                            Haight-Ashbury  Vegetarian / Vegan Restaurant
# 3   Hayes Valley/Tenderloin/North of Market            American Restaurant
# 4        Ingelside-Excelsior/Crocker-Amazon          Vietnamese Restaurant
# 5              Inner Mission/Bernal Heights             Mexican Restaurant
# 6                            Inner Richmond             Chinese Restaurant
# 7                               Lake Merced             Mexican Restaurant
# 8                                    Marina             Italian Restaurant
# 9                     North Beach/Chinatown             Italian Restaurant
# 10                           Outer Richmond            Japanese Restaurant
# 11                     Parkside/Forest Hill             Chinese Restaurant
# 12             Polk/Russian Hill (Nob Hill)             Italian Restaurant
# 13                             Potrero Hill       Mediterranean Restaurant
# 14                          South of Market                     Restaurant
# 15                                   Sunset          Vietnamese Restaurant
# 16                     Twin Peaks-Glen Park             Dim Sum Restaurant
# 17               Western Addition/Japantown          Vietnamese Restaurant
#
#             2nd Most Common Venue    3rd Most Common Venue  \
# 0              Seafood Restaurant      Szechuan Restaurant
# 1              Italian Restaurant         Sushi Restaurant
# 2           Vietnamese Restaurant      Filipino Restaurant
# 3   Vegetarian / Vegan Restaurant    Vietnamese Restaurant
# 4              Mexican Restaurant       Chinese Restaurant
# 5         New American Restaurant      American Restaurant
# 6                Sushi Restaurant        Korean Restaurant
# 7           Vietnamese Restaurant      Filipino Restaurant
# 8               French Restaurant       Mexican Restaurant
# 9              Chinese Restaurant         Sushi Restaurant
# 10             Chinese Restaurant  New American Restaurant
# 11            Dumpling Restaurant    Vietnamese Restaurant
# 12               Sushi Restaurant    Vietnamese Restaurant
# 13            Dumpling Restaurant    Vietnamese Restaurant
# 14                Thai Restaurant     Ethiopian Restaurant
# 15            Szechuan Restaurant       Chinese Restaurant
# 16          Vietnamese Restaurant      Filipino Restaurant
# 17            American Restaurant  New American Restaurant
#
#               4th Most Common Venue          5th Most Common Venue
# 0               Japanese Restaurant            American Restaurant
# 1              Cantonese Restaurant          Vietnamese Restaurant
# 2                 Jewish Restaurant            Japanese Restaurant
# 3   Southern / Soul Food Restaurant               Malay Restaurant
# 4         Latin American Restaurant                Thai Restaurant
# 5                 Indian Restaurant             Chinese Restaurant
# 6               Japanese Restaurant           Fast Food Restaurant
# 7               Japanese Restaurant      Japanese Curry Restaurant
# 8               American Restaurant  Vegetarian / Vegan Restaurant
# 9                Mexican Restaurant      Latin American Restaurant
# 10                 Ramen Restaurant          Vietnamese Restaurant
# 11              American Restaurant            Japanese Restaurant
# 12              American Restaurant             Seafood Restaurant
# 13              Filipino Restaurant            Japanese Restaurant
# 14                 Sushi Restaurant  Vegetarian / Vegan Restaurant
# 15                Indian Restaurant      Middle Eastern Restaurant
# 16                Jewish Restaurant            Japanese Restaurant
# 17                 Sushi Restaurant               Asian Restaurant

# %% [markdown]
# #### **Cluster Neighborhoods**

# %%
# set number of clusters
kclusters = 5

sf_grouped_clustering = sf_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(sf_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([0, 0, 3, 0, 0, 0, 0, 2, 0, 0], dtype=int32)

# %%
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)
sf_merged = df2
sf_merged = sf_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')
sf_merged
# Out:
#     zipcode                             Neighborhood   latitude   longitude  \
# 0     94102  Hayes Valley/Tenderloin/North of Market  37.779278 -122.416582
# 1     94103                          South of Market  37.775678 -122.412131
# 2     94107                             Potrero Hill  37.769029 -122.393681
# 3     94108                                Chinatown  37.791028 -122.408782
# 4     94109             Polk/Russian Hill (Nob Hill)  37.795219 -122.420782
# 5     94110             Inner Mission/Bernal Heights  37.748932 -122.416281
# 6     94112       Ingelside-Excelsior/Crocker-Amazon  37.721981 -122.439382
# 7     94114                        Castro/Noe Valley  37.758279 -122.439332
# 8     94115               Western Addition/Japantown  37.786028 -122.437032
# 9     94116                     Parkside/Forest Hill  37.743857 -122.483232
# 10    94117                           Haight-Ashbury  37.769079 -122.443882
# 11    94118                           Inner Richmond  37.778779 -122.459982
# 12    94121                           Outer Richmond  37.777129 -122.491682
# 13    94122                                   Sunset  37.761179 -122.475732
# 14    94123                                   Marina  37.799670 -122.435732
# 15    94124                    Bayview-Hunters Point  37.731230 -122.382857
# 16    94127    St. Francis Wood/Miraloma/West Portal  37.734030 -122.458632
# 17    94131                     Twin Peaks-Glen Park  37.743630 -122.443182
# 18    94132                              Lake Merced  37.722631 -122.482483
# 19    94133                    North Beach/Chinatown  37.801928 -122.410182
# 20    94134              Visitacion Valley/Sunnydale  37.721680 -122.410832
#
#              city state         county  Cluster Labels  \
# 0   San Francisco    CA  San Francisco             0.0
# 1   San Francisco    CA  San Francisco             0.0
# 2   San Francisco    CA  San Francisco             4.0
# 3   San Francisco    CA  San Francisco             0.0
# 4   San Francisco    CA  San Francisco             0.0
# 5   San Francisco    CA  San Francisco             0.0
# 6   San Francisco    CA  San Francisco             0.0
# 7   San Francisco    CA  San Francisco             0.0
# 8   San Francisco    CA  San Francisco             0.0
# 9   San Francisco    CA  San Francisco             0.0
# 10  San Francisco    CA  San Francisco             3.0
# 11  San Francisco    CA  San Francisco             0.0
# 12  San Francisco    CA  San Francisco             0.0
# 13  San Francisco    CA  San Francisco             0.0
# 14  San Francisco    CA  San Francisco             0.0
# 15  San Francisco    CA  San Francisco             NaN
# 16  San Francisco    CA  San Francisco             NaN
# 17  San Francisco    CA  San Francisco             1.0
# 18  San Francisco    CA  San Francisco             2.0
# 19  San Francisco    CA  San Francisco             0.0
# 20  San Francisco    CA  San Francisco             NaN
#
#             1st Most Common Venue          2nd Most Common Venue  \
# 0             American Restaurant  Vegetarian / Vegan Restaurant
# 1                      Restaurant                Thai Restaurant
# 2        Mediterranean Restaurant            Dumpling Restaurant
# 3             American Restaurant             Italian Restaurant
# 4              Italian Restaurant               Sushi Restaurant
# 5              Mexican Restaurant        New American Restaurant
# 6           Vietnamese Restaurant             Mexican Restaurant
# 7                 Thai Restaurant             Seafood Restaurant
# 8           Vietnamese Restaurant            American Restaurant
# 9              Chinese Restaurant            Dumpling Restaurant
# 10  Vegetarian / Vegan Restaurant          Vietnamese Restaurant
# 11             Chinese Restaurant               Sushi Restaurant
# 12            Japanese Restaurant             Chinese Restaurant
# 13          Vietnamese Restaurant            Szechuan Restaurant
# 14             Italian Restaurant              French Restaurant
# 15                            NaN                            NaN
# 16                            NaN                            NaN
# 17             Dim Sum Restaurant          Vietnamese Restaurant
# 18             Mexican Restaurant          Vietnamese Restaurant
# 19             Italian Restaurant             Chinese Restaurant
# 20                            NaN                            NaN
#
#       3rd Most Common Venue            4th Most Common Venue  \
# 0     Vietnamese Restaurant  Southern / Soul Food Restaurant
# 1      Ethiopian Restaurant                 Sushi Restaurant
# 2     Vietnamese Restaurant              Filipino Restaurant
# 3          Sushi Restaurant             Cantonese Restaurant
# 4     Vietnamese Restaurant              American Restaurant
# 5       American Restaurant                Indian Restaurant
# 6        Chinese Restaurant        Latin American Restaurant
# 7       Szechuan Restaurant              Japanese Restaurant
# 8   New American Restaurant                 Sushi Restaurant
# 9     Vietnamese Restaurant              American Restaurant
# 10      Filipino Restaurant                Jewish Restaurant
# 11        Korean Restaurant              Japanese Restaurant
# 12  New American Restaurant                 Ramen Restaurant
# 13       Chinese Restaurant                Indian Restaurant
# 14       Mexican Restaurant              American Restaurant
# 15                      NaN                              NaN
# 16                      NaN                              NaN
# 17      Filipino Restaurant                Jewish Restaurant
# 18      Filipino Restaurant              Japanese Restaurant
# 19         Sushi Restaurant               Mexican Restaurant
# 20                      NaN                              NaN
#
#             5th Most Common Venue
# 0                Malay Restaurant
# 1   Vegetarian / Vegan Restaurant
# 2             Japanese Restaurant
# 3           Vietnamese Restaurant
# 4              Seafood Restaurant
# 5              Chinese Restaurant
# 6                 Thai Restaurant
# 7             American Restaurant
# 8                Asian Restaurant
# 9             Japanese Restaurant
# 10            Japanese Restaurant
# 11           Fast Food Restaurant
# 12          Vietnamese Restaurant
# 13      Middle Eastern Restaurant
# 14  Vegetarian / Vegan Restaurant
# 15                            NaN
# 16                            NaN
# 17            Japanese Restaurant
# 18      Japanese Curry Restaurant
# 19      Latin American Restaurant
# 20                            NaN

# %%
df3=pd.merge(neighborhoods_venues_sorted,df2, on="Neighborhood")
df3
# Out:
#     Cluster Labels                             Neighborhood  \
# 0                0                        Castro/Noe Valley
# 1                0                                Chinatown
# 2                3                           Haight-Ashbury
# 3                0  Hayes Valley/Tenderloin/North of Market
# 4                0       Ingelside-Excelsior/Crocker-Amazon
# 5                0             Inner Mission/Bernal Heights
# 6                0                           Inner Richmond
# 7                2                              Lake Merced
# 8                0                                   Marina
# 9                0                    North Beach/Chinatown
# 10               0                           Outer Richmond
# 11               0                     Parkside/Forest Hill
# 12               0             Polk/Russian Hill (Nob Hill)
# 13               4                             Potrero Hill
# 14               0                          South of Market
# 15               0                                   Sunset
# 16               1                     Twin Peaks-Glen Park
# 17               0               Western Addition/Japantown
#
#             1st Most Common Venue          2nd Most Common Venue  \
# 0                 Thai Restaurant             Seafood Restaurant
# 1             American Restaurant             Italian Restaurant
# 2   Vegetarian / Vegan Restaurant          Vietnamese Restaurant
# 3             American Restaurant  Vegetarian / Vegan Restaurant
# 4           Vietnamese Restaurant             Mexican Restaurant
# 5              Mexican Restaurant        New American Restaurant
# 6              Chinese Restaurant               Sushi Restaurant
# 7              Mexican Restaurant          Vietnamese Restaurant
# 8              Italian Restaurant              French Restaurant
# 9              Italian Restaurant             Chinese Restaurant
# 10            Japanese Restaurant             Chinese Restaurant
# 11             Chinese Restaurant            Dumpling Restaurant
# 12             Italian Restaurant               Sushi Restaurant
# 13       Mediterranean Restaurant            Dumpling Restaurant
# 14                     Restaurant                Thai Restaurant
# 15          Vietnamese Restaurant            Szechuan Restaurant
# 16             Dim Sum Restaurant          Vietnamese Restaurant
# 17          Vietnamese Restaurant            American Restaurant
#
#       3rd Most Common Venue            4th Most Common Venue  \
# 0       Szechuan Restaurant              Japanese Restaurant
# 1          Sushi Restaurant             Cantonese Restaurant
# 2       Filipino Restaurant                Jewish Restaurant
# 3     Vietnamese Restaurant  Southern / Soul Food Restaurant
# 4        Chinese Restaurant        Latin American Restaurant
# 5       American Restaurant                Indian Restaurant
# 6         Korean Restaurant              Japanese Restaurant
# 7       Filipino Restaurant              Japanese Restaurant
# 8        Mexican Restaurant              American Restaurant
# 9          Sushi Restaurant               Mexican Restaurant
# 10  New American Restaurant                 Ramen Restaurant
# 11    Vietnamese Restaurant              American Restaurant
# 12    Vietnamese Restaurant              American Restaurant
# 13    Vietnamese Restaurant              Filipino Restaurant
# 14     Ethiopian Restaurant                 Sushi Restaurant
# 15       Chinese Restaurant                Indian Restaurant
# 16      Filipino Restaurant                Jewish Restaurant
# 17  New American Restaurant                 Sushi Restaurant
#
#             5th Most Common Venue  zipcode   latitude   longitude  \
# 0             American Restaurant    94114  37.758279 -122.439332
# 1           Vietnamese Restaurant    94108  37.791028 -122.408782
# 2             Japanese Restaurant    94117  37.769079 -122.443882
# 3                Malay Restaurant    94102  37.779278 -122.416582
# 4                 Thai Restaurant    94112  37.721981 -122.439382
# 5              Chinese Restaurant    94110  37.748932 -122.416281
# 6            Fast Food Restaurant    94118  37.778779 -122.459982
# 7       Japanese Curry Restaurant    94132  37.722631 -122.482483
# 8   Vegetarian / Vegan Restaurant    94123  37.799670 -122.435732
# 9       Latin American Restaurant    94133  37.801928 -122.410182
# 10          Vietnamese Restaurant    94121  37.777129 -122.491682
# 11            Japanese Restaurant    94116  37.743857 -122.483232
# 12             Seafood Restaurant    94109  37.795219 -122.420782
# 13            Japanese Restaurant    94107  37.769029 -122.393681
# 14  Vegetarian / Vegan Restaurant    94103  37.775678 -122.412131
# 15      Middle Eastern Restaurant    94122  37.761179 -122.475732
# 16            Japanese Restaurant    94131  37.743630 -122.443182
# 17               Asian Restaurant    94115  37.786028 -122.437032
#
#              city state         county
# 0   San Francisco    CA  San Francisco
# 1   San Francisco    CA  San Francisco
# 2   San Francisco    CA  San Francisco
# 3   San Francisco    CA  San Francisco
# 4   San Francisco    CA  San Francisco
# 5   San Francisco    CA  San Francisco
# 6   San Francisco    CA  San Francisco
# 7   San Francisco    CA  San Francisco
# 8   San Francisco    CA  San Francisco
# 9   San Francisco    CA  San Francisco
# 10  San Francisco    CA  San Francisco
# 11  San Francisco    CA  San Francisco
# 12  San Francisco    CA  San Francisco
# 13  San Francisco    CA  San Francisco
# 14  San Francisco    CA  San Francisco
# 15  San Francisco    CA  San Francisco
# 16  San Francisco    CA  San Francisco
# 17  San Francisco    CA  San Francisco

# %%
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=12)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(df3['latitude'], df3['longitude'], df3['Neighborhood'], df3['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
